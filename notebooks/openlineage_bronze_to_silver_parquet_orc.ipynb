# %% [markdown]
# # Bronze to Silver (Iceberg -> Parquet + ORC)
#
# This notebook:
# - reads Bronze Iceberg table from the source-to-bronze notebook
# - applies simple transformations (filter, rename, cast) and writes Parquet
# - applies simple aggregations (group by) and writes ORC

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
import os

# %%
# Iceberg + output settings
WAREHOUSE_PATH = "/home/jovyan/work/data/lakehouse/warehouse"
BRONZE_TABLE = "local.bronze.marquez_raw"

SILVER_BASE_DIR = "/home/jovyan/work/data/silver"
SILVER_TRANSFORMED_PATH = os.path.join(SILVER_BASE_DIR, "marquez_transformed_parquet")
SILVER_AGG_PATH = os.path.join(SILVER_BASE_DIR, "marquez_aggregated_orc")

spark = (
    SparkSession.builder
    .appName("bronze-to-silver-marquez")
    .config("spark.jars.packages", "org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.6.1")
    .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions")
    .config("spark.sql.catalog.local", "org.apache.iceberg.spark.SparkCatalog")
    .config("spark.sql.catalog.local.type", "hadoop")
    .config("spark.sql.catalog.local.warehouse", WAREHOUSE_PATH)
    .getOrCreate()
)

spark.version
# Out:
# '3.5.3'

# %%
bronze_df = spark.table(BRONZE_TABLE)
print("Bronze rows:", bronze_df.count())
bronze_df.printSchema()
bronze_df.show(20, truncate=False)
# Out:
# Bronze rows: 153
# root
#  |-- event_time: timestamp (nullable = true)
#  |-- event: string (nullable = true)
#  |-- event_type: string (nullable = true)
#  |-- job_name: string (nullable = true)
#  |-- job_namespace: string (nullable = true)
#  |-- producer: string (nullable = true)
#  |-- run_uuid: string (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#  |-- _event_type: string (nullable = true)
#  |-- ingestion_ts: timestamp (nullable = true)
#
# +-----------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |event_time             |event                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# +-----------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |2026-02-24 09:17:42.27 |{"job": {"name": "openlineage_demo", "facets": {"jobType": {"jobType": "APPLICATION", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "NONE"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef0-b18e-7e3b-941f-09db966af52e", "facets": {"spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}, "spark_applicationDetails": {"master": "local[*]", "appName": "openlineage-demo", "uiWebUrl": "http://a32755f280ce:4040", "userName": "jovyan", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "deployMode": "client", "driverHost": "a32755f280ce", "applicationId": "local-1771924663330"}}}, "inputs": [], "outputs": [], "producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "eventTime": "2026-02-24T09:17:42.27Z", "eventType": "START", "schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunEvent"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# |2026-02-24 09:17:49.236|{"job": {"name": "openlineage_demo.collect_limit", "facets": {"jobType": {"jobType": "SQL_JOB", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "BATCH"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef0-c8d9-7155-ba55-ea97c7951e32", "facets": {"parent": {"job": {"name": "openlineage_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef0-b18e-7e3b-941f-09db966af52e"}, "root": {"job": {"name": "openlineage_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef0-b18e-7e3b-941f-09db966af52e"}}, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-0/ParentRunFacet.json#/$defs/ParentRunFacet"}, "spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}}}, "inputs": [{"name": "/home/jovyan/work/data/people.csv", "facets": {"schema": {"fields": [{"name": "value", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 43, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}], "outputs": [], "producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "eventTime": "2026-02-24T09:17:49.236Z", "eventType": "COMPLETE", "schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunEvent"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# |2026-02-24 09:17:49.865|{"job": {"name": "openlineage_demo.collect_limit", "facets": {"jobType": {"jobType": "SQL_JOB", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "BATCH"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef0-ddf6-7825-96dc-ff2bbbd72a36", "facets": {"parent": {"job": {"name": "openlineage_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef0-b18e-7e3b-941f-09db966af52e"}, "root": {"job": {"name": "openlineage_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef0-b18e-7e3b-941f-09db966af52e"}}, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-0/ParentRunFacet.json#/$defs/ParentRunFacet"}, "spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}}}, "inputs": [{"name": "/home/jovyan/work/data/people.csv", "facets": {"schema": {"fields": [{"name": "id", "type": "string"}, {"name": "name", "type": "string"}, {"name": "age", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 43, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}], "outputs": [], "producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "eventTime": "2026-02-24T09:17:49.865Z", "eventType": "COMPLETE", "schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunEvent"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# |2026-02-24 09:17:53.391|{"job": {"name": "openlineage_demo.execute_insert_into_hadoop_fs_relation_command.data_people_parquet", "facets": {"jobType": {"jobType": "SQL_JOB", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "BATCH"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef0-df2c-7b59-a596-90a5f24a3b36", "facets": {"parent": {"job": {"name": "openlineage_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef0-b18e-7e3b-941f-09db966af52e"}, "root": {"job": {"name": "openlineage_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef0-b18e-7e3b-941f-09db966af52e"}}, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-0/ParentRunFacet.json#/$defs/ParentRunFacet"}, "spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}}}, "inputs": [{"name": "/home/jovyan/work/data/people.csv", "facets": {"schema": {"fields": [{"name": "id", "type": "string"}, {"name": "name", "type": "string"}, {"name": "age", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 43, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}], "outputs": [{"name": "/home/jovyan/work/data/people_parquet", "facets": {"schema": {"fields": [{"name": "id", "type": "string"}, {"name": "full_name", "type": "string"}, {"name": "age", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}, "columnLineage": {"fields": {"id": {"inputFields": [{"name": "/home/jovyan/work/data/people.csv", "field": "id", "namespace": "file", "transformations": [{"type": "DIRECT", "masking": false, "subtype": "IDENTITY", "description": ""}]}]}, "age": {"inputFields": [{"name": "/home/jovyan/work/data/people.csv", "field": "age", "namespace": "file", "transformations": [{"type": "DIRECT", "masking": false, "subtype": "IDENTITY", "description": ""}]}]}, "full_name": {"inputFields": [{"name": "/home/jovyan/work/data/people.csv", "field": "name", "namespace": "file", "transformations": [{"type": " ...
# |2026-02-24 09:18:55.951|{"job": {"name": "openlineage_complex_demo", "facets": {"jobType": {"jobType": "APPLICATION", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "NONE"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8", "facets": {"spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-complex-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}, "spark_applicationDetails": {"master": "local[*]", "appName": "openlineage-complex-demo", "uiWebUrl": "http://a32755f280ce:4041", "userName": "jovyan", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "deployMode": "client", "driverHost": "a32755f280ce", "applicationId": "local-1771924738304"}}}, "inputs": [], "outputs": [], "producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "eventTime": "2026-02-24T09:18:55.951Z", "eventType": "START", "schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunEvent"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# |2026-02-24 09:19:15.43 |{"job": {"name": "openlineage_complex_demo.adaptive_spark_plan", "facets": {"jobType": {"jobType": "SQL_JOB", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "BATCH"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef2-13ec-7026-8698-390c32c0d7a3", "facets": {"parent": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}, "root": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}}, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-0/ParentRunFacet.json#/$defs/ParentRunFacet"}, "spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-complex-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}, "spark_applicationDetails": {"master": "local[*]", "appName": "openlineage-complex-demo", "uiWebUrl": "http://a32755f280ce:4041", "userName": "jovyan", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "deployMode": "client", "driverHost": "a32755f280ce", "applicationId": "local-1771924738304"}}}, "inputs": [{"name": "/home/jovyan/work/data/complex_demo/source/products.csv", "facets": {"schema": {"fields": [{"name": "product_id", "type": "string"}, {"name": "product_name", "type": "string"}, {"name": "category", "type": "string"}, {"name": "is_active", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 163, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}, {"name": "/home/jovyan/work/data/complex_demo/source/fx_rates.csv", "facets": {"schema": {"fields": [{"name": "currency", "type": "string"}, {"name": "rate_to_usd", "type": "string"}, {"name": "effective_date", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 116, "_produc ...
# |2026-02-24 09:19:15.628|{"job": {"name": "openlineage_complex_demo.adaptive_spark_plan", "facets": {"jobType": {"jobType": "SQL_JOB", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "BATCH"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef2-13ec-7026-8698-390c32c0d7a3", "facets": {"parent": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}, "root": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}}, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-0/ParentRunFacet.json#/$defs/ParentRunFacet"}, "spark_jobDetails": {"jobId": 12, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet"}, "spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-complex-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}, "spark_applicationDetails": {"master": "local[*]", "appName": "openlineage-complex-demo", "uiWebUrl": "http://a32755f280ce:4041", "userName": "jovyan", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "deployMode": "client", "driverHost": "a32755f280ce", "applicationId": "local-1771924738304"}}}, "inputs": [{"name": "/home/jovyan/work/data/complex_demo/source/products.csv", "facets": {"schema": {"fields": [{"name": "product_id", "type": "string"}, {"name": "product_name", "type": "string"}, {"name": "category", "type": "string"}, {"name": "is_active", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 163, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}, {"name": "/home/jovyan/work/data/complex_demo/source/fx_rates.csv", "facets": {"schema": {"fields": [{"name": "currency", "type": "string"}, {"name": "rate_to_usd", "type": "string"}, {"name": "effective_date", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integrat ...
# |2026-02-24 09:19:20.508|{"job": {"name": "openlineage_complex_demo.adaptive_spark_plan.silver_orders_scored", "facets": {"jobType": {"jobType": "SQL_JOB", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "BATCH"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef2-2d90-71e9-96d6-31436290e573", "facets": {"parent": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}, "root": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}}, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-0/ParentRunFacet.json#/$defs/ParentRunFacet"}, "spark_jobDetails": {"jobId": 20, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet"}, "spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-complex-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}, "spark_applicationDetails": {"master": "local[*]", "appName": "openlineage-complex-demo", "uiWebUrl": "http://a32755f280ce:4041", "userName": "jovyan", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "deployMode": "client", "driverHost": "a32755f280ce", "applicationId": "local-1771924738304"}}}, "inputs": [{"name": "/home/jovyan/work/data/complex_demo/source/products.csv", "facets": {"schema": {"fields": [{"name": "product_id", "type": "string"}, {"name": "product_name", "type": "string"}, {"name": "category", "type": "string"}, {"name": "is_active", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 163, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}, {"name": "/home/jovyan/work/data/complex_demo/source/fx_rates.csv", "facets": {"schema": {"fields": [{"name": "currency", "type": "string"}, {"name": "rate_to_usd", "type": "string"}, {"name": "effective_date", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage ...
# ...
# |2026-02-24 09:19:16.924|{"job": {"name": "openlineage_complex_demo.adaptive_spark_plan", "facets": {"jobType": {"jobType": "SQL_JOB", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "BATCH"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef2-13ec-7026-8698-390c32c0d7a3", "facets": {"parent": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}, "root": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}}, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-0/ParentRunFacet.json#/$defs/ParentRunFacet"}, "spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-complex-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}}}, "inputs": [{"name": "/home/jovyan/work/data/complex_demo/source/products.csv", "facets": {"schema": {"fields": [{"name": "product_id", "type": "string"}, {"name": "product_name", "type": "string"}, {"name": "category", "type": "string"}, {"name": "is_active", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 163, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}, {"name": "/home/jovyan/work/data/complex_demo/source/fx_rates.csv", "facets": {"schema": {"fields": [{"name": "currency", "type": "string"}, {"name": "rate_to_usd", "type": "string"}, {"name": "effective_date", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 116, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}, {"name": "/home/jovyan/work/data/complex_demo/source/orders.csv", "facets": {"schema": {"fields": [{"name": "order_id", "type": "string"}, {"name": "customer_id", "type": "string"}, {" ...
# |2026-02-24 09:19:17.423|{"job": {"name": "openlineage_complex_demo.adaptive_spark_plan.silver_customers_curated", "facets": {"jobType": {"jobType": "SQL_JOB", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "BATCH"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef2-25ff-7e6a-9bae-063eaa96fe20", "facets": {"parent": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}, "root": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}}, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-0/ParentRunFacet.json#/$defs/ParentRunFacet"}, "spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-complex-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}}}, "inputs": [{"name": "/home/jovyan/work/data/complex_demo/source/customers.csv", "facets": {"schema": {"fields": [{"name": "customer_id", "type": "string"}, {"name": "full_name", "type": "string"}, {"name": "country", "type": "string"}, {"name": "segment", "type": "string"}, {"name": "updated_at", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 276, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}], "outputs": [{"name": "/home/jovyan/work/data/complex_demo/silver/customers_curated", "facets": {"schema": {"fields": [{"name": "customer_id", "type": "integer"}, {"name": "full_name", "type": "string"}, {"name": "country", "type": "string"}, {"name": "segment", "type": "string"}, {"name": "updated_at", "type": "timestamp"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}, "columnLineage": {"fields": {"country": {"inputFields": [{"name": "/home/jovyan/work/data/complex_demo/source/customers.csv", "field": "country", "namespace": "file", "transformations": [{"type": "DIRECT", "masking": false, "subtype": "IDENTITY", "description": ""}]}]}, "segment": {"inputFields": [{"name": "/home/jovyan/work/data/complex ...
# +-----------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 20 rows

# %%
# Helpers for dynamic column selection
columns = bronze_df.columns

preferred_business_cols = ["event_type", "name", "namespace_name", "namespace", "type", "job_name"]
business_col = next((c for c in preferred_business_cols if c in columns), None)
if business_col is None:
    business_col = next((c for c in columns if c != "ingestion_ts"), None)

if business_col is None:
    raise RuntimeError("No business column found to transform")

print("Business column selected:", business_col)
# Out:
# Business column selected: event_type

# %%
# 2.1 Transformations: filter + rename + cast -> Parquet
silver_transformed_df = (
    bronze_df
    .filter(F.col(business_col).isNotNull())
    .withColumn("entity_value", F.col(business_col).cast("string"))
    .withColumn("ingestion_ts", F.col("ingestion_ts").cast("timestamp"))
    .withColumn("ingestion_date", F.to_date("ingestion_ts"))
    .drop(business_col)
)

silver_transformed_df.show(20, truncate=False)
os.makedirs(SILVER_BASE_DIR, exist_ok=True)
silver_transformed_df.write.mode("overwrite").parquet(SILVER_TRANSFORMED_PATH)

print("Transformed Parquet saved to:", SILVER_TRANSFORMED_PATH)
# Out:
# +-----------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |event_time             |event                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# +-----------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |2026-02-24 09:17:42.27 |{"job": {"name": "openlineage_demo", "facets": {"jobType": {"jobType": "APPLICATION", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "NONE"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef0-b18e-7e3b-941f-09db966af52e", "facets": {"spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}, "spark_applicationDetails": {"master": "local[*]", "appName": "openlineage-demo", "uiWebUrl": "http://a32755f280ce:4040", "userName": "jovyan", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "deployMode": "client", "driverHost": "a32755f280ce", "applicationId": "local-1771924663330"}}}, "inputs": [], "outputs": [], "producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "eventTime": "2026-02-24T09:17:42.27Z", "eventType": "START", "schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunEvent"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# |2026-02-24 09:17:49.236|{"job": {"name": "openlineage_demo.collect_limit", "facets": {"jobType": {"jobType": "SQL_JOB", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "BATCH"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef0-c8d9-7155-ba55-ea97c7951e32", "facets": {"parent": {"job": {"name": "openlineage_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef0-b18e-7e3b-941f-09db966af52e"}, "root": {"job": {"name": "openlineage_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef0-b18e-7e3b-941f-09db966af52e"}}, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-0/ParentRunFacet.json#/$defs/ParentRunFacet"}, "spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}}}, "inputs": [{"name": "/home/jovyan/work/data/people.csv", "facets": {"schema": {"fields": [{"name": "value", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 43, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}], "outputs": [], "producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "eventTime": "2026-02-24T09:17:49.236Z", "eventType": "COMPLETE", "schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunEvent"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# |2026-02-24 09:17:49.865|{"job": {"name": "openlineage_demo.collect_limit", "facets": {"jobType": {"jobType": "SQL_JOB", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "BATCH"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef0-ddf6-7825-96dc-ff2bbbd72a36", "facets": {"parent": {"job": {"name": "openlineage_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef0-b18e-7e3b-941f-09db966af52e"}, "root": {"job": {"name": "openlineage_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef0-b18e-7e3b-941f-09db966af52e"}}, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-0/ParentRunFacet.json#/$defs/ParentRunFacet"}, "spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}}}, "inputs": [{"name": "/home/jovyan/work/data/people.csv", "facets": {"schema": {"fields": [{"name": "id", "type": "string"}, {"name": "name", "type": "string"}, {"name": "age", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 43, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}], "outputs": [], "producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "eventTime": "2026-02-24T09:17:49.865Z", "eventType": "COMPLETE", "schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunEvent"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# |2026-02-24 09:17:53.391|{"job": {"name": "openlineage_demo.execute_insert_into_hadoop_fs_relation_command.data_people_parquet", "facets": {"jobType": {"jobType": "SQL_JOB", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "BATCH"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef0-df2c-7b59-a596-90a5f24a3b36", "facets": {"parent": {"job": {"name": "openlineage_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef0-b18e-7e3b-941f-09db966af52e"}, "root": {"job": {"name": "openlineage_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef0-b18e-7e3b-941f-09db966af52e"}}, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-0/ParentRunFacet.json#/$defs/ParentRunFacet"}, "spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}}}, "inputs": [{"name": "/home/jovyan/work/data/people.csv", "facets": {"schema": {"fields": [{"name": "id", "type": "string"}, {"name": "name", "type": "string"}, {"name": "age", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 43, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}], "outputs": [{"name": "/home/jovyan/work/data/people_parquet", "facets": {"schema": {"fields": [{"name": "id", "type": "string"}, {"name": "full_name", "type": "string"}, {"name": "age", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}, "columnLineage": {"fields": {"id": {"inputFields": [{"name": "/home/jovyan/work/data/people.csv", "field": "id", "namespace": "file", "transformations": [{"type": "DIRECT", "masking": false, "subtype": "IDENTITY", "description": ""}]}]}, "age": {"inputFields": [{"name": "/home/jovyan/work/data/people.csv", "field": "age", "namespace": "file", "transformations": [{"type": "DIRECT", "masking": false, "subtype": "IDENTITY", "description": ""}]}]}, "full_name": {"inputFields": [{"name": "/home/jovyan/work/data/people.csv", "field": "name", "namespace": "file", "transformations": [{"type": " ...
# |2026-02-24 09:18:55.951|{"job": {"name": "openlineage_complex_demo", "facets": {"jobType": {"jobType": "APPLICATION", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "NONE"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8", "facets": {"spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-complex-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}, "spark_applicationDetails": {"master": "local[*]", "appName": "openlineage-complex-demo", "uiWebUrl": "http://a32755f280ce:4041", "userName": "jovyan", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "deployMode": "client", "driverHost": "a32755f280ce", "applicationId": "local-1771924738304"}}}, "inputs": [], "outputs": [], "producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "eventTime": "2026-02-24T09:18:55.951Z", "eventType": "START", "schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunEvent"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# |2026-02-24 09:19:15.43 |{"job": {"name": "openlineage_complex_demo.adaptive_spark_plan", "facets": {"jobType": {"jobType": "SQL_JOB", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "BATCH"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef2-13ec-7026-8698-390c32c0d7a3", "facets": {"parent": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}, "root": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}}, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-0/ParentRunFacet.json#/$defs/ParentRunFacet"}, "spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-complex-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}, "spark_applicationDetails": {"master": "local[*]", "appName": "openlineage-complex-demo", "uiWebUrl": "http://a32755f280ce:4041", "userName": "jovyan", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "deployMode": "client", "driverHost": "a32755f280ce", "applicationId": "local-1771924738304"}}}, "inputs": [{"name": "/home/jovyan/work/data/complex_demo/source/products.csv", "facets": {"schema": {"fields": [{"name": "product_id", "type": "string"}, {"name": "product_name", "type": "string"}, {"name": "category", "type": "string"}, {"name": "is_active", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 163, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}, {"name": "/home/jovyan/work/data/complex_demo/source/fx_rates.csv", "facets": {"schema": {"fields": [{"name": "currency", "type": "string"}, {"name": "rate_to_usd", "type": "string"}, {"name": "effective_date", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 116, "_produc ...
# |2026-02-24 09:19:15.628|{"job": {"name": "openlineage_complex_demo.adaptive_spark_plan", "facets": {"jobType": {"jobType": "SQL_JOB", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "BATCH"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef2-13ec-7026-8698-390c32c0d7a3", "facets": {"parent": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}, "root": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}}, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-0/ParentRunFacet.json#/$defs/ParentRunFacet"}, "spark_jobDetails": {"jobId": 12, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet"}, "spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-complex-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}, "spark_applicationDetails": {"master": "local[*]", "appName": "openlineage-complex-demo", "uiWebUrl": "http://a32755f280ce:4041", "userName": "jovyan", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "deployMode": "client", "driverHost": "a32755f280ce", "applicationId": "local-1771924738304"}}}, "inputs": [{"name": "/home/jovyan/work/data/complex_demo/source/products.csv", "facets": {"schema": {"fields": [{"name": "product_id", "type": "string"}, {"name": "product_name", "type": "string"}, {"name": "category", "type": "string"}, {"name": "is_active", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 163, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}, {"name": "/home/jovyan/work/data/complex_demo/source/fx_rates.csv", "facets": {"schema": {"fields": [{"name": "currency", "type": "string"}, {"name": "rate_to_usd", "type": "string"}, {"name": "effective_date", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integrat ...
# |2026-02-24 09:19:20.508|{"job": {"name": "openlineage_complex_demo.adaptive_spark_plan.silver_orders_scored", "facets": {"jobType": {"jobType": "SQL_JOB", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "BATCH"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef2-2d90-71e9-96d6-31436290e573", "facets": {"parent": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}, "root": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}}, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-0/ParentRunFacet.json#/$defs/ParentRunFacet"}, "spark_jobDetails": {"jobId": 20, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet"}, "spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-complex-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}, "spark_applicationDetails": {"master": "local[*]", "appName": "openlineage-complex-demo", "uiWebUrl": "http://a32755f280ce:4041", "userName": "jovyan", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "deployMode": "client", "driverHost": "a32755f280ce", "applicationId": "local-1771924738304"}}}, "inputs": [{"name": "/home/jovyan/work/data/complex_demo/source/products.csv", "facets": {"schema": {"fields": [{"name": "product_id", "type": "string"}, {"name": "product_name", "type": "string"}, {"name": "category", "type": "string"}, {"name": "is_active", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 163, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}, {"name": "/home/jovyan/work/data/complex_demo/source/fx_rates.csv", "facets": {"schema": {"fields": [{"name": "currency", "type": "string"}, {"name": "rate_to_usd", "type": "string"}, {"name": "effective_date", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage ...
# ...
# |2026-02-24 09:19:16.924|{"job": {"name": "openlineage_complex_demo.adaptive_spark_plan", "facets": {"jobType": {"jobType": "SQL_JOB", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "BATCH"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef2-13ec-7026-8698-390c32c0d7a3", "facets": {"parent": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}, "root": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}}, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-0/ParentRunFacet.json#/$defs/ParentRunFacet"}, "spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-complex-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}}}, "inputs": [{"name": "/home/jovyan/work/data/complex_demo/source/products.csv", "facets": {"schema": {"fields": [{"name": "product_id", "type": "string"}, {"name": "product_name", "type": "string"}, {"name": "category", "type": "string"}, {"name": "is_active", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 163, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}, {"name": "/home/jovyan/work/data/complex_demo/source/fx_rates.csv", "facets": {"schema": {"fields": [{"name": "currency", "type": "string"}, {"name": "rate_to_usd", "type": "string"}, {"name": "effective_date", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 116, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}, {"name": "/home/jovyan/work/data/complex_demo/source/orders.csv", "facets": {"schema": {"fields": [{"name": "order_id", "type": "string"}, {"name": "customer_id", "type": "string"}, {" ...
# |2026-02-24 09:19:17.423|{"job": {"name": "openlineage_complex_demo.adaptive_spark_plan.silver_customers_curated", "facets": {"jobType": {"jobType": "SQL_JOB", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/2-0-3/JobTypeJobFacet.json#/$defs/JobTypeJobFacet", "integration": "SPARK", "processingType": "BATCH"}}, "namespace": "local-spark"}, "run": {"runId": "019c8ef2-25ff-7e6a-9bae-063eaa96fe20", "facets": {"parent": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}, "root": {"job": {"name": "openlineage_complex_demo", "namespace": "local-spark"}, "run": {"runId": "019c8ef1-d8f6-752f-841e-679fe736dea8"}}, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-0/ParentRunFacet.json#/$defs/ParentRunFacet"}, "spark_properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "properties": {"spark.master": "local[*]", "spark.app.name": "openlineage-complex-demo"}}, "processing_engine": {"name": "spark", "version": "3.5.3", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-1-1/ProcessingEngineRunFacet.json#/$defs/ProcessingEngineRunFacet", "openlineageAdapterVersion": "1.44.0"}, "environment-properties": {"_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/2-0-2/OpenLineage.json#/$defs/RunFacet", "environment-properties": {}}}}, "inputs": [{"name": "/home/jovyan/work/data/complex_demo/source/customers.csv", "facets": {"schema": {"fields": [{"name": "customer_id", "type": "string"}, {"name": "full_name", "type": "string"}, {"name": "country", "type": "string"}, {"name": "segment", "type": "string"}, {"name": "updated_at", "type": "string"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}}, "namespace": "file", "inputFacets": {"inputStatistics": {"size": 276, "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "fileCount": 1, "_schemaURL": "https://openlineage.io/spec/facets/1-0-0/InputStatisticsInputDatasetFacet.json#/$defs/InputStatisticsInputDatasetFacet"}}}], "outputs": [{"name": "/home/jovyan/work/data/complex_demo/silver/customers_curated", "facets": {"schema": {"fields": [{"name": "customer_id", "type": "integer"}, {"name": "full_name", "type": "string"}, {"name": "country", "type": "string"}, {"name": "segment", "type": "string"}, {"name": "updated_at", "type": "timestamp"}], "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-2-0/SchemaDatasetFacet.json#/$defs/SchemaDatasetFacet"}, "dataSource": {"uri": "file", "name": "file", "_producer": "https://github.com/OpenLineage/OpenLineage/tree/1.44.0/integration/spark", "_schemaURL": "https://openlineage.io/spec/facets/1-0-1/DatasourceDatasetFacet.json#/$defs/DatasourceDatasetFacet"}, "columnLineage": {"fields": {"country": {"inputFields": [{"name": "/home/jovyan/work/data/complex_demo/source/customers.csv", "field": "country", "namespace": "file", "transformations": [{"type": "DIRECT", "masking": false, "subtype": "IDENTITY", "description": ""}]}]}, "segment": {"inputFields": [{"name": "/home/jovyan/work/data/complex ...
# +-----------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 20 rows
#
# Transformed Parquet saved to: /home/jovyan/work/data/silver/marquez_transformed_parquet

# %%
# 2.2 Aggregations: group by -> ORC
silver_agg_df = (
    silver_transformed_df
    .groupBy("ingestion_date", "entity_value")
    .agg(F.count(F.lit(1)).alias("row_count"))
    .orderBy(F.col("row_count").desc(), F.col("ingestion_date"), F.col("entity_value"))
)

silver_agg_df.show(50, truncate=False)
silver_agg_df.write.mode("overwrite").orc(SILVER_AGG_PATH)

print("Aggregated ORC saved to:", SILVER_AGG_PATH)
# Out:
# +--------------+------------+---------+
# |ingestion_date|entity_value|row_count|
# +--------------+------------+---------+
# |2026-02-24    |RUNNING     |49       |
# |2026-02-24    |COMPLETE    |43       |
# |2026-02-24    |START       |21       |
# +--------------+------------+---------+
#
# Aggregated ORC saved to: /home/jovyan/work/data/silver/marquez_aggregated_orc

# %% [markdown]
# ## Notes
#
# - This notebook expects `local.bronze.marquez_raw` to already exist.
# - If you changed Bronze table name, update `BRONZE_TABLE` before running.
